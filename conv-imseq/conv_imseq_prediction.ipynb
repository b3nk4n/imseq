# %%
import os
import sys
import time

import cv2
import numpy as np
import tensorflow as tf

import model.conv_deconv_model as model

# %%
# VIDEO_FILE = 'tmp/UCF11_updated_mpg/golf_swing/v_golf_10/v_golf_10_02.mpg'
VIDEO_FILE = 'tmp/UCF11_updated_mpg/tennis_swing/v_tennis_01/v_tennis_01_01.mpg'
TRAIN_DIR = 'train_10k_5seq'

INPUT_SEQ_LENGTH = 5

PREDICTION_LENGTH = 120
GROUND_TRUTH_LENGTH = 30

FRAME_WIDTH = 320
FRAME_HEIGHT = 240
FRAME_CHANNELS = 3

LAMBDA = 5e-4

BATCH_SIZE = 1

GPU_MEMORY_FRACTION = 0.5

# %%
# TODO: refactor
def open_video(videofile, from_time=0):
    vidcap = cv2.VideoCapture(videofile)
    if from_time != 0:
        vidcap.set(cv2.CAP_PROP_POS_MSEC, from_time)
    return vidcap

# TODO: refactor
def read_next_frame(vidcap):
    success, image = vidcap.read()
    if success:
        return image
    else:
        return None

# %%
def get_video_writer(filename):
    # Define the codec and create VideoWriter object
    # fourcc = cv2.VideoWriter_fourcc(*'XVID')
    fourcc = cv2.cv.CV_FOURCC(*'XVID')
    out = cv2.VideoWriter('{}.avi'.format(filename), fourcc, 24.0, (320,240))
    return out

# %% [markdown]
# # MAIN

# %%
def save_frame(name, frame):
    if not os.path.exists('video-frame-out'):
        os.makedirs('video-frame-out')
    filename = 'video-frame-out/{}.png'.format(name)
    print('Writing frame {}'.format(filename))
    cv2.imwrite(filename, frame)

# %%
with tf.Graph().as_default():
    seq_batch = tf.placeholder(tf.float32, shape=[1, FRAME_HEIGHT, FRAME_WIDTH, FRAME_CHANNELS * INPUT_SEQ_LENGTH])
    
    # with tf.device(GPU_TO_USE):
    # build graph and compute predictions from the inference model
    model_output = model.inference(seq_batch, BATCH_SIZE, FRAME_HEIGHT, FRAME_WIDTH, FRAME_CHANNELS,
                                   INPUT_SEQ_LENGTH, LAMBDA)

    # Create a saver and merge all summaries
    saver = tf.train.Saver(tf.all_variables())

    # Create a session for running operations in the Graph
    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=GPU_MEMORY_FRACTION)
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_options)) as sess:
        checkpoint_path = os.path.join(TRAIN_DIR, 'model.ckpt-10000')
        saver.restore(sess, checkpoint_path)
        
        vidcap = open_video(VIDEO_FILE, 0)
        vidwriter = get_video_writer('predicted_video')
        
        input_frames = []
        
        for i in xrange(GROUND_TRUTH_LENGTH):
            frame = read_next_frame(vidcap)
            
            if frame is not None:
                vidwriter.write(frame)

                if i >= GROUND_TRUTH_LENGTH - INPUT_SEQ_LENGTH:
                    frame = (frame - 128.0) / 128.0
                    input_frames.append(frame)
            else:
                print('Warning: Error while reading frame.')
        
        for j in xrange(PREDICTION_LENGTH):
            seq_input = np.concatenate([input_frames[0], input_frames[1], input_frames[2], input_frames[3], input_frames[4]],
                                       axis=2)
            seq_input = np.expand_dims(seq_input, axis=0)
            
            predicted_frame = sess.run([model_output], feed_dict={seq_batch: seq_input})
            predicted_frame = np.squeeze(predicted_frame)
            np.place(predicted_frame, predicted_frame > 1, [1])
            np.place(predicted_frame, predicted_frame < -1, [-1])
            print(np.min(predicted_frame))
            print(np.max(predicted_frame))
            video_frame = predicted_frame * 128.0 + 128.0
            np.place(video_frame, video_frame > 255, [255]) # values are 0-256?!
            save_frame(str(j) + '-float', video_frame)
            video_frame = video_frame.astype(np.uint8)
            save_frame(str(j), video_frame)
            print(np.min(video_frame))
            print(np.max(video_frame))
            vidwriter.write(video_frame)
            
            del input_frames[-1]
            input_frames.insert(0, predicted_frame)
            
        vidwriter.release()
        vidcap.release()
# Out:
# -1.0
# 1.0
# Writing frame video-frame-out/0-float.png
# Writing frame video-frame-out/0.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/1-float.png
# Writing frame video-frame-out/1.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/2-float.png
# Writing frame video-frame-out/2.png
# 0
# 255
# -0.969447
# 1.0
# Writing frame video-frame-out/3-float.png
# Writing frame video-frame-out/3.png
# 3
# 255
# -0.982431
# 1.0
# Writing frame video-frame-out/4-float.png
# Writing frame video-frame-out/4.png
# 2
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/5-float.png
# Writing frame video-frame-out/5.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/6-float.png
# Writing frame video-frame-out/6.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/7-float.png
# Writing frame video-frame-out/7.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/8-float.png
# Writing frame video-frame-out/8.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/9-float.png
# Writing frame video-frame-out/9.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/10-float.png
# Writing frame video-frame-out/10.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/11-float.png
# Writing frame video-frame-out/11.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/12-float.png
# Writing frame video-frame-out/12.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/13-float.png
# Writing frame video-frame-out/13.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/14-float.png
# Writing frame video-frame-out/14.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/15-float.png
# Writing frame video-frame-out/15.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/16-float.png
# Writing frame video-frame-out/16.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/17-float.png
# Writing frame video-frame-out/17.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/18-float.png
# Writing frame video-frame-out/18.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/19-float.png
# Writing frame video-frame-out/19.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/20-float.png
# Writing frame video-frame-out/20.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/21-float.png
# Writing frame video-frame-out/21.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/22-float.png
# Writing frame video-frame-out/22.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/23-float.png
# Writing frame video-frame-out/23.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/24-float.png
# Writing frame video-frame-out/24.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/25-float.png
# Writing frame video-frame-out/25.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/26-float.png
# Writing frame video-frame-out/26.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/27-float.png
# Writing frame video-frame-out/27.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/28-float.png
# Writing frame video-frame-out/28.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/29-float.png
# Writing frame video-frame-out/29.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/30-float.png
# Writing frame video-frame-out/30.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/31-float.png
# Writing frame video-frame-out/31.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/32-float.png
# Writing frame video-frame-out/32.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/33-float.png
# Writing frame video-frame-out/33.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/34-float.png
# Writing frame video-frame-out/34.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/35-float.png
# Writing frame video-frame-out/35.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/36-float.png
# Writing frame video-frame-out/36.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/37-float.png
# Writing frame video-frame-out/37.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/38-float.png
# Writing frame video-frame-out/38.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/39-float.png
# Writing frame video-frame-out/39.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/40-float.png
# Writing frame video-frame-out/40.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/41-float.png
# Writing frame video-frame-out/41.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/42-float.png
# Writing frame video-frame-out/42.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/43-float.png
# Writing frame video-frame-out/43.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/44-float.png
# Writing frame video-frame-out/44.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/45-float.png
# Writing frame video-frame-out/45.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/46-float.png
# Writing frame video-frame-out/46.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/47-float.png
# Writing frame video-frame-out/47.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/48-float.png
# Writing frame video-frame-out/48.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/49-float.png
# Writing frame video-frame-out/49.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/50-float.png
# Writing frame video-frame-out/50.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/51-float.png
# Writing frame video-frame-out/51.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/52-float.png
# Writing frame video-frame-out/52.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/53-float.png
# Writing frame video-frame-out/53.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/54-float.png
# Writing frame video-frame-out/54.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/55-float.png
# Writing frame video-frame-out/55.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/56-float.png
# Writing frame video-frame-out/56.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/57-float.png
# Writing frame video-frame-out/57.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/58-float.png
# Writing frame video-frame-out/58.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/59-float.png
# Writing frame video-frame-out/59.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/60-float.png
# Writing frame video-frame-out/60.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/61-float.png
# Writing frame video-frame-out/61.png
# 0
# 255
# -0.91205
# 1.0
# Writing frame video-frame-out/62-float.png
# Writing frame video-frame-out/62.png
# 11
# 255
# -0.94802
# 1.0
# Writing frame video-frame-out/63-float.png
# Writing frame video-frame-out/63.png
# 6
# 255
# -0.970381
# 1.0
# Writing frame video-frame-out/64-float.png
# Writing frame video-frame-out/64.png
# 3
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/65-float.png
# Writing frame video-frame-out/65.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/66-float.png
# Writing frame video-frame-out/66.png
# 0
# 255
# -0.845461
# 1.0
# Writing frame video-frame-out/67-float.png
# Writing frame video-frame-out/67.png
# 19
# 255
# -0.845318
# 1.0
# Writing frame video-frame-out/68-float.png
# Writing frame video-frame-out/68.png
# 19
# 255
# -0.997624
# 1.0
# Writing frame video-frame-out/69-float.png
# Writing frame video-frame-out/69.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/70-float.png
# Writing frame video-frame-out/70.png
# 0
# 255
# -0.998281
# 1.0
# Writing frame video-frame-out/71-float.png
# Writing frame video-frame-out/71.png
# 0
# 255
# -0.863184
# 1.0
# Writing frame video-frame-out/72-float.png
# Writing frame video-frame-out/72.png
# 17
# 255
# -0.883493
# 1.0
# Writing frame video-frame-out/73-float.png
# Writing frame video-frame-out/73.png
# 14
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/74-float.png
# Writing frame video-frame-out/74.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/75-float.png
# Writing frame video-frame-out/75.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/76-float.png
# Writing frame video-frame-out/76.png
# 0
# 255
# -0.895298
# 1.0
# Writing frame video-frame-out/77-float.png
# Writing frame video-frame-out/77.png
# 13
# 255
# -0.932176
# 1.0
# Writing frame video-frame-out/78-float.png
# Writing frame video-frame-out/78.png
# 8
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/79-float.png
# Writing frame video-frame-out/79.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/80-float.png
# Writing frame video-frame-out/80.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/81-float.png
# Writing frame video-frame-out/81.png
# 0
# 255
# -0.935543
# 1.0
# Writing frame video-frame-out/82-float.png
# Writing frame video-frame-out/82.png
# 8
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/83-float.png
# Writing frame video-frame-out/83.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/84-float.png
# Writing frame video-frame-out/84.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/85-float.png
# Writing frame video-frame-out/85.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/86-float.png
# Writing frame video-frame-out/86.png
# 0
# 255
# -0.982469
# 1.0
# Writing frame video-frame-out/87-float.png
# Writing frame video-frame-out/87.png
# 2
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/88-float.png
# Writing frame video-frame-out/88.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/89-float.png
# Writing frame video-frame-out/89.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/90-float.png
# Writing frame video-frame-out/90.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/91-float.png
# Writing frame video-frame-out/91.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/92-float.png
# Writing frame video-frame-out/92.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/93-float.png
# Writing frame video-frame-out/93.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/94-float.png
# Writing frame video-frame-out/94.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/95-float.png
# Writing frame video-frame-out/95.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/96-float.png
# Writing frame video-frame-out/96.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/97-float.png
# Writing frame video-frame-out/97.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/98-float.png
# Writing frame video-frame-out/98.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/99-float.png
# Writing frame video-frame-out/99.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/100-float.png
# Writing frame video-frame-out/100.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/101-float.png
# Writing frame video-frame-out/101.png
# 0
# 255
# -1.0
# 0.942236
# Writing frame video-frame-out/102-float.png
# Writing frame video-frame-out/102.png
# 0
# 248
# -1.0
# 1.0
# Writing frame video-frame-out/103-float.png
# Writing frame video-frame-out/103.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/104-float.png
# Writing frame video-frame-out/104.png
# 0
# 255
# -1.0
# 0.918397
# Writing frame video-frame-out/105-float.png
# Writing frame video-frame-out/105.png
# 0
# 245
# -1.0
# 1.0
# Writing frame video-frame-out/106-float.png
# Writing frame video-frame-out/106.png
# 0
# 255
# -1.0
# 0.809497
# Writing frame video-frame-out/107-float.png
# Writing frame video-frame-out/107.png
# 0
# 231
# -1.0
# 1.0
# Writing frame video-frame-out/108-float.png
# Writing frame video-frame-out/108.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/109-float.png
# Writing frame video-frame-out/109.png
# 0
# 255
# -1.0
# 0.961258
# Writing frame video-frame-out/110-float.png
# Writing frame video-frame-out/110.png
# 0
# 251
# -1.0
# 1.0
# Writing frame video-frame-out/111-float.png
# Writing frame video-frame-out/111.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/112-float.png
# Writing frame video-frame-out/112.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/113-float.png
# Writing frame video-frame-out/113.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/114-float.png
# Writing frame video-frame-out/114.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/115-float.png
# Writing frame video-frame-out/115.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/116-float.png
# Writing frame video-frame-out/116.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/117-float.png
# Writing frame video-frame-out/117.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/118-float.png
# Writing frame video-frame-out/118.png
# 0
# 255
# -1.0
# 1.0
# Writing frame video-frame-out/119-float.png
# Writing frame video-frame-out/119.png
# 0
# 255
